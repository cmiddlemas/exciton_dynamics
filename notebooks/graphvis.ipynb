# %%
import networkx as nx

# %%
G = nx.star_graph(16)
nx.draw(G)

# %%
G = nx.cycle_graph(16)
nx.draw(G)

# %%
G = nx.circulant_graph(16,[1,2,3])
nx.draw(G)

# %%
G = nx.wheel_graph(16)
nx.draw(G)

# %%
G = nx.random_regular_expander_graph(64,4)
nx.draw(G)

# %%
G = nx.grid_2d_graph(4,4,periodic=True)
nx.draw(G)

# %%
G = nx.hypercube_graph(6)
nx.draw(G)

# %%
G = nx.gnp_random_graph(64, 0.2)
nx.draw(G)

# %%
G = nx.watts_strogatz_graph(64, 2, 0.1)
nx.draw(G)

# %%
G = nx.random_regular_graph(3, 64)
nx.draw(G)

# %%
G = nx.random_regular_graph(3, 64)
nx.draw(G)

# %%
G = nx.gnm_random_graph(64, 64*3)
nx.draw(G)

# %%
G = nx.complete_graph(5)
nx.draw(G)
